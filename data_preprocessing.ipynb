# %% [markdown]
# # Preprocess NYT corpus

# %%
import os
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import random

try:
    import snap
except:
    os.chdir('/Users/yiweiluo/Downloads/snap-4.0.0-4.0-macosx10.9.5-x64-py2.7') # Add this path to your 'pythonpath'
    import snap

try: 
    import utils
except:
    os.chdir('/Users/yiweiluo/Dropbox/cs224w') # Add this path to your 'pythonpath'
    import utils

# %matplotlib inline

font = {'family' : 'normal',
        'size'   : 12}

matplotlib.rc('font', **font)
# Out:
# [nltk_data] Downloading package state_union to
# [nltk_data]     /Users/yiweiluo/nltk_data...
# [nltk_data]   Package state_union is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/yiweiluo/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/yiweiluo/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
import utils

# %%
folder = 'NYT/2006/';
filename = 'NYT2006_processed_lemmatize';

articleList = utils.extract_corpus(folder, extract=True)
utils.save_data(filename, articleList)
# Out:
# extracting NYT/2006/01.tgz
# extracting NYT/2006/02.tgz
# extracting NYT/2006/03.tgz
# extracting NYT/2006/04.tgz
# extracting NYT/2006/05.tgz
# extracting NYT/2006/06.tgz
# extracting NYT/2006/07.tgz
# extracting NYT/2006/08.tgz
# extracting NYT/2006/09.tgz
# extracting NYT/2006/10.tgz
# extracting NYT/2006/11.tgz
# extracting NYT/2006/12.tgz
# 100: NYT/2006/01\01\1728765.xml: Headline = The 5th Annual Year in Ideas, 01/01/06
# Error (<type 'exceptions.IndexError'>) while parsing file = NYT/2006/01\01\1728819.xml
# 200: NYT/2006/01\01\1728866.xml: Headline = 'City of a Million Bugs', 01/01/06
# 300: NYT/2006/01\01\1728966.xml: Headline = New Yorkers Who Earn The Minimum Get a Raise, 01/01/06
# 400: NYT/2006/01\01\1729066.xml: Headline = Paid Notice: Deaths   FORD, MARY LOUISE MCGOVERN, 01/01/06
# 500: NYT/2006/01\02\1729166.xml: Headline = At 150 Edgars Lane, Changing the Idea of Home, 02/01/06
# ...

# %%
# Load and sample
articleList = utils.load_data(filename)

for k in range(3):
    a = random.choice(articleList);
    a.article_info()
